# %% [markdown]
# # Challenge 3: Start coding
#
# ## Introduction
#
# In this challenge you will interact with OpenAI and Phi-3 APIs using Python.
# You can use the following notebook schema and complete the code or you can create your own notebook from scretch.
#
# the Steps to complete the challenge are:
# - Play with the vanilla models
# - Bring your own data
#
# Be sure you have your python environment activated

# %% [markdown]
# ## Step 1: Play with the vanilla models
#
# in this step you need to connect to the Azure OpenAI and Phi-3 APIs using code.
#
# ### Azure OpenAI API
#
# Let's start with Azure OpenAI API.
#
# - Provide the question as prompt (you can use questions from the first part of the challenge)
# - Create the OpenAI API client.
# - Use the OpenAI API client to generate completions
# - Print the completions
# - Print the number of tokens used in the prompt and the completion.
#
# <div class="alert alert-block alert-warning">
# Be Sure you populated correctly the `.env` file as requested in the previous challenge.
# We are using <a href="https://pypi.org/project/python-dotenv/">python-dotenv</a> to manager our environment variables. It will also make things easier when deploying the application in Azure.
# </div>

# %%
import os, dotenv
dotenv.load_dotenv(override=True)

# Setup environment
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")
AZURE_OPENAI_MODEL = os.getenv("AZURE_OPENAI_MODEL")
AZURE_OPENAI_DEPLOYMENT_NAME = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")

# Libraries
from openai import AzureOpenAI

# %%
# Define the questions list (if you are using your own dataset you need to change this list)
QUESTIONS = [
  "What are the revenues of GOOGLE in the year 2009?",
  "What are the revenues and the operative margins of ALPHABET Inc. in 2022 and how it compares with the previous year?",
  "Can you create a table with the total revenue for ALPHABET, NVIDIA, MICROSOFT and APPLE in year 2023?",
  "Can you give me the Fiscal Year 2023 Highlights for APPLE, MICROSOFT and NVIDIA?",
  "Did APPLE repurchase common stock in 2023? create a table of APPLE repurchased stock with date, numbers of stocks and values in dollars.",
  "What is the value of the cumulative 5-years total return of ALPHABET Class A at December 2022?",
  "What was the price of APPLE, NVIDIA and MICROSOFT stock in 23/07/2024?",
  "Can you buy 10 shares of APPLE for me?"
  ]

# Define the System prompt (you need to update this is you are using your own dataset.)
system_prompt = """ You are a financial assistant tasked with answering questions related to the financial results of major technology companies listed on NASDAQ, \n
specifically Microsoft (MSFT), Alphabet Inc. (GOOGL), Nvidia (NVDA), Apple Inc. (AAPL), and Amazon (AMZN). \n
if you don't find the answer in the context, just say `I don't know.`"""

# %%
# Create an Azure OpenAI client

# Use the client to generate completions (client.chat.completions.create), cycle through the questions list and print the response and the number of tokens in the response (response.usage.prompt_tokens/response.usage.completion_tokens)
# For the message you can use the system role with the content oyu prepared for Azure AI Foundry. 
client = AzureOpenAI(
    api_key=AZURE_OPENAI_API_KEY,
    api_version=AZURE_OPENAI_API_VERSION,
    azure_endpoint=AZURE_OPENAI_ENDPOINT
)

for question in QUESTIONS:
    response = client.chat.completions.create(
        model=AZURE_OPENAI_DEPLOYMENT_NAME,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": question}
        ]
    )
    answer = response.choices[0].message.content
    prompt_tokens = response.usage.prompt_tokens
    completion_tokens = response.usage.completion_tokens
    print(f"Q: {question}")
    print(f"A: {answer}")
    print(f"Prompt tokens: {prompt_tokens}, Completion tokens: {completion_tokens}")
    print("-" * 50)
# Out:
# Q: What are the revenues of GOOGLE in the year 2009?
# A: I don't know.
# Prompt tokens: 99, Completion tokens: 5
# --------------------------------------------------
# Q: What are the revenues and the operative margins of ALPHABET Inc. in 2022 and how it compares with the previous year?
# A: I don't know.
# Prompt tokens: 113, Completion tokens: 5
# --------------------------------------------------
# Q: Can you create a table with the total revenue for ALPHABET, NVIDIA, MICROSOFT and APPLE in year 2023?
# A: I don’t know.
# Prompt tokens: 114, Completion tokens: 6
# --------------------------------------------------
# Q: Can you give me the Fiscal Year 2023 Highlights for APPLE, MICROSOFT and NVIDIA?
# A: I don't know.
# Prompt tokens: 107, Completion tokens: 5
# --------------------------------------------------
# Q: Did APPLE repurchase common stock in 2023? create a table of APPLE repurchased stock with date, numbers of stocks and values in dollars.
# A: I don't know.
# Prompt tokens: 118, Completion tokens: 5
# --------------------------------------------------
# Q: What is the value of the cumulative 5-years total return of ALPHABET Class A at December 2022?
# A: I don't know.
# Prompt tokens: 110, Completion tokens: 5
# --------------------------------------------------
# Q: What was the price of APPLE, NVIDIA and MICROSOFT stock in 23/07/2024?
# A: I don't know.
# Prompt tokens: 109, Completion tokens: 5
# --------------------------------------------------
# Q: Can you buy 10 shares of APPLE for me?
# A: I don't have the capability to execute trades or make financial transactions. You would need to use a brokerage account to buy shares of Apple or any other stock. Please contact your brokerage or financial advisor for assistance.
# Prompt tokens: 98, Completion tokens: 42
# --------------------------------------------------

# %% [markdown]
# ### Phi-3 API
#
# Now let's do the same using the Phi-3 API.
#
# the steps are similar to the Azure OpenAI API.
#
# - Populate environment variables based on the MaaS deployed in Azure AI Studio.
# - You can reuse the questions from the previous code block (no need to rewrite them).
# - Create the OpenAI API client.
# - Use the OpenAI API client to generate completions
# - Print the completions
# - Print the number of tokens used in the prompt and the completion.

# %%
import os, dotenv
dotenv.load_dotenv()

# Setup environment
PHI_API_KEY = os.getenv("PHI_API_KEY")
PHI_ENDPOINT = os.getenv("PHI_ENDPOINT")
PHI_DEPLOYMENT_NAME = os.getenv("PHI_DEPLOYMENT_NAME")

# Libraries
from openai import OpenAI

# %%
# Create an Azure OpenAI client

# Use the client to generate completions

# %% [markdown]
# ## Step 2: Bring your own data
#
# After the test of the vanilla models, now it's time to bring your data into the picture.
#
#
# We will use Langchain framework and Azure AI Search for this.
#
# Remember what you learned from Challenge 0 regarding the RAG end-to-end process.
# - Index
#     - Load (Document Loader)
#     - Split (Text Splitters)
#     - Store (Vector Stores and Embeddings)
# - Retrieve
# - Generate
#
#
# ### Azure OpenAI API
#
# - Populate environment variables based on the MaaS deployed in Azure AI Studio.
# - Create a Search Vector Store. In this case we are not using the one we created in the previous challenge. **You need to create a new one and call it "itsarag-ch3-001"**.
# - Create the Azure Open AI embedding and the Azure Chat OpenAI objects.
# - Index : Load documents from the data source (you can use AzureBlobStorageContainerLoader)
# - Index : Split the documents in chucks (you can use the RecursiveCharacterTextSplitter)
# - Index : Store the documents in the vector store (you can use the add_documents method)
# - Retrieve: Create a retriver using the Vector Store (SimilaritySearch and top_k)
# - Generate: Use the langchain chain to generate completions (get context from retriever and format the context in single line with the question -> add the proper prompt -> send to LLM -> get structured output)

# %%
# ENVIRONMENT VARIABLES
# OpenAI
AZURE_OPENAI_EMBEDDING = os.getenv("AZURE_OPENAI_EMBEDDING")
AZURE_OPENAI_MODEL_VERSION = os.getenv("AZURE_OPENAI_MODEL_VERSION")
# Azure Search
AZURE_SEARCH_ENDPOINT = os.getenv("AZURE_SEARCH_ENDPOINT")
AZURE_SEARCH_API_KEY = os.getenv("AZURE_SEARCH_API_KEY")
# Azure Blob Storage
AZURE_STORAGE_CONNECTION_STRING = os.getenv("AZURE_STORAGE_CONNECTION_STRING")
AZURE_STORAGE_CONTAINER = os.getenv("AZURE_STORAGE_CONTAINER")
# Import Libraries
from langchain_openai import AzureOpenAIEmbeddings, AzureChatOpenAI
from langchain_community.vectorstores.azuresearch import AzureSearch
from langchain_community.document_loaders import AzureBlobStorageContainerLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# %%
# Azure OpenAI Embeddings
embeddings = AzureOpenAIEmbeddings(
    azure_deployment=AZURE_OPENAI_EMBEDDING,
    api_key=AZURE_OPENAI_API_KEY,
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
    api_version=AZURE_OPENAI_API_VERSION
)

# Azure Search Vector Store
vector_store = AzureSearch(
    azure_search_endpoint=AZURE_SEARCH_ENDPOINT,
    azure_search_key=AZURE_SEARCH_API_KEY,
    index_name="itsarag-ch3-001",
    embedding_function=embeddings.embed_query
)

# LLM model
llm = AzureChatOpenAI(
    azure_deployment=AZURE_OPENAI_DEPLOYMENT_NAME,
    api_key=AZURE_OPENAI_API_KEY,
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
    api_version=AZURE_OPENAI_API_VERSION
)

# %%
# Index: Load the documents
# Load the document from Azure Blob Storage (AzureBlobStorageContainerLoader)
loader = AzureBlobStorageContainerLoader(
    conn_str=AZURE_STORAGE_CONNECTION_STRING,
    container=AZURE_STORAGE_CONTAINER
)
documents = loader.load()
# Note: It can take up to 5 minutes.

# %%
# Index: Split (RecursiveCharacterTextSplitter - 1000 characters - 200 overlap)
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)
splitted_docs = text_splitter.split_documents(documents)

# %%
# Index: Store (add_documents)
# Note: It can take up to 8 minutes.
store_chunked_documents = vector_store.add_documents(splitted_docs)
# Out:
# ['NThlN2Q4NGItMDQ3Ni00OWVhLWI2MjgtNTgwMzJjNjc3Nzdh',
#  'NWNhNWE4NmItZDdiMS00ZjMwLWEzOWItNjg2NTZlNzMwNjUy',
#  'YmE0Y2ZmOGUtMTQzZS00YTFjLWE5NjItZjkyZTVkOTA2MTcw',
#  'Zjk3ZTljZWEtMzBkNy00NDM4LTlmYTctNmNkMzE5NmNlMGY0',
#  'MzUwZjgwYjEtYTcyNy00OTBmLWE4ZGUtNTk4YmRmNjNjNGRm',
#  'MDQzNThjMDEtNWNiMy00OTUzLWE0MTYtMTU5YzI0ZGI5NGI1',
#  'NDg5ZDQzNjctNjdmMi00N2MwLTg5YTYtN2I3MDhiNmMxZTVk',
#  'ODYzMzlmZTMtM2MwOS00MGEzLTgyMWMtNTk1YWMwMmIyZGZm',
#  'NTI1MzA5YTYtY2UwYy00NzVjLTg3YTUtMzBmM2ViNzljZDg0',
#  'YTI4Zjk2ODEtNjEyZS00ZGZiLTk1MzAtMmQ1MjMyNzI0YjJk',
#  'ZTVkNGUyMjUtOWJhYS00MGRjLTlmNDYtZjdlYTkxNWJiYzI4',
#  'Y2I4NjA0MTItY2E2YS00ODk1LTg0NmMtNTY2NDhkYzcxOGVk',
#  'MWRjMmFiOTQtNDEyOC00MzM1LWE2ZWYtYjZhMzRlNjQ2MjJk',
#  'NjYwOTRiOTQtNWUzZi00ZmI5LThmM2EtZGQ4NTFmZmE5MzMy',
#  'YWYxNmE2MTktNzU1MC00YzRiLTliYTAtNmI0M2VlZWQ1Yjky',
#  'ODcyZWEwMzItNmY1ZS00MTExLTlmMzMtYjg1NGVjYTA5MmE0',
#  'MGRkZWFkN2ItYTNjOS00OWM1LTg3NGUtYTA0ODlkMjQyYjA5',
#  'NjRkYzQ2MmUtMDMyOS00ODY0LWIyM2ItZDE0YzYyOTJkYzc4',
#  'NjM1ZDY2MTMtNGQ5Zi00ZDA2LWFlYmQtN2IwZTU0MzcwZTE5',
#  'ZmRiZDU1YTgtNzg0Yi00MGNlLTkwMjMtYzEzNWY4NjU2MDA2',
#  'MzAyNWI2NGEtYzgxOS00MDNiLWEyOWUtY2MzYmUzMTE3ZTFm',
#  'ZjNkMjFkMGQtZGRmNy00ODY5LWIyZTQtMjEwZjI5NjQ0ZjJm',
#  'NGUxNzZhNDMtOTA4My00NWU3LTgwY2QtNDY1NTI2YTVmMWRi',
#  'NmEwZGVmZmUtZGYwNS00NTExLWIwNWUtNWNmNmM2Y2M3OWVi',
#  'YWNjODdlZDctMGZmZS00MDUxLThhMzktNTA4YzI4YTZmOGM5',
#  'Y2E2Y2I4YTItNThkZi00ZmZmLTgxZmYtOTRhMjc5MTg3NzQw',
#  'NzhjOThjODctM2EzNy00N2M4LWIwNDUtMDJhMzQyOWNjODJi',
#  'M2MzNDkwMDctNzcxMi00MDNiLTk3ODYtZjg4YWMxYWEwY2Fk',
#  'OTkzMDQwZDYtYjBlNC00MmM1LWJiY2MtMTMyOWJhNTY0YjYx',
#  'MDk2ZDk2MDgtYTUyYy00OWE0LTlhMzctOWQ4YTU5YmUzMGYw',
#  'NWEzYmFjNTctZWNmNS00NGMzLTg0MTEtMmNiNGYyODIwN2Yx',
#  'NDRlNGE5ZDQtODljOC00ZTgzLWIxNDgtZDQ3NTRiYTZiYTA1',
#  'ODVhZGFiNmItYTdhYy00ZWI1LTllMDItOGI4NzVlNzc0OTc0',
#  'OWU3MTMzZWQtMWQ4MS00ODhiLThhMzEtY2RmZmNiNTA4ODI3',
#  'NzUwM2U3ZGUtNjRhYy00YTEyLTg5MDQtNGY4MTgxMDU1OWQy',
#  'YTY2NzdjNjctZjM3Yi00ZDgzLWJlOTMtZDM4MzU1YTYxM2Q3',
#  'OGM3ZjgyZjgtYTE2Ny00YzZhLTg1OTgtNDVmODY0ZjA3ZmY0',
#  'NmY5ODQ0YjUtNjZkMi00YzRmLWJhZTAtZjUyNmFmOTA4NGE2',
#  'OWEwNTkxMWQtMTEzOC00ZGE3LTk0NmUtZGUwZTBhNThmZjhh',
#  'ZjkyNzgyYjYtN2Q1OC00MDI3LTg5ZGYtMWE5ZmVmNzk0Yjcx',
#  'NzRlZDJhNjgtMjY2NC00YjE5LWI4ZTItYmQ1MGNlNmI4NjU3',
#  'OGU3MDM2YzMtZmE2Yi00OGY4LTkyNzQtNWM2YWZlZTZhZGNk',
#  'MDE3N2U0NmQtNDFkMC00NGUxLThjYjQtZTAyZTI0MjYyNmZh',
#  'MWQwOTJmMGUtOTRlNS00Nzg4LTg4NmEtMDU2YjZjOGY3Zjc4',
#  'ODdiZmJmOTItMDY5OC00YTBhLWEzZWItYmMyMmRkYjU2NWI0',
#  'NDgwYThlMGItZjJlMS00NzViLTg3ZGYtNmMzZGJlNDY5MTQ4',
#  'ZDBkZThhMzktOTQzYy00YTdkLTk1ZDAtNjY1ZmMwMDMyOGI1',
#  'OGZiZjhlZjktNDgxZS00NTlmLWI1MDAtZDRmMjcxYzNkN2Y0',
#  'NjFlODllZDItOTk5Yy00YmM2LThhOTMtNmFiZDFkNjZhZmY4',
#  'NWQxMDI4N2EtMmNkYy00NzQ0LWIzZmItNGZkN2Y2MGQ1MmNl',
#  'YzM5YTZkNTMtMTJhNi00OWI5LTgzMDItZjYxZDhjYjI4Mzcw',
#  'Y2FkOWY2NmUtYzljOC00MTEwLTlmMzItMDEyYWEzZDE4MDM2',
#  'YTViNDM4MGUtNGY3Ny00MTY5LWFjMzQtZWE3ODYwMjRkODQy',
#  'OTcxNWM2OWQtNzZmMy00YTRlLTg4NjItYzA0OGIyNDM4NTQx',
#  'MTNjNzQ4YWMtNjkyOC00N2E4LWFmMjctNmIyYWJiYzhlZWEy',
#  'ODkxMjYxZDAtM2E4My00YmVkLWEyYzktOGIwZTJlMDczZTk3',
#  'OGU5MTUwNzAtZTBhYi00YzlkLWI2ZWItMTAwZjZhNjYyM2My',
#  'MWVlMzliOTItZDU4Ni00ZGUxLWJkY2EtMjViZjEwODkyZGYy',
#  'ZDczZTI0ZjEtNGE1Zi00ZjFkLTg2NzktZDEwYjRkYzhkNDU3',
#  'YTYwYTdmOTItMGUxYy00ODJhLTk0ZTUtNzBkZmI1ZDQ1MmM3',
#  'OTEyMmE1MWEtZWU1Ni00ZjdkLWEwNDMtNzg1NGMyMDQ5ZTJh',
#  'NzQ5N2UyNzQtNmY3OS00ZDg4LTkwODctMzEzZjMwNDIxNjE1',
#  'MTc4ZDAyNjAtOTE1Ni00MWM1LThhOGYtNzM3YTMwZjM4ODY4',
#  'MzE4YTA0OGUtZGFjYS00YmFmLWE2Y2EtNGE0MTNlZGQxZmQw',
#  'ZGE0NzA3M2EtMThjYS00ZjE4LWFkMDYtN2U3ZWRlNTY4YzAw',
#  'YTUyNTE1YjYtNDA2Ni00NTc0LWFhYTItNTIxMDYzOGMwOGRm',
#  'MTM0NzI3MGYtOGIyMy00ZTUwLTkzN2YtOWQ0OTIwYTcwYjQ5',
#  'YzRlOThiZjEtNTNlZS00NzMxLWE3NDctYjg0Y2E0OWYwMDg3',
#  'Y2RlMjU0ZjItMmQ2NS00NDZjLTljYWYtZjlhMmY5OWU4NzAz',
#  'MWI2NjJmYmEtN2YzNS00NWNhLTg2NjYtMGZmZGI2NTM3Yzgy',
#  'NjA1MjAzYWEtM2IxZS00YzRiLTk4ZGYtZWFjZWFlZDdhYzA3',
#  'Njc3MTkwNjItYWJmMS00Y2QxLTg4MTktY2NjNmE4MDQxYzcy',
#  'MjVmN2Y1MTctZTJmNS00YTI1LWExNWMtNjZmMjM5YzI3ZDY4',
#  'MjVjZmU1ODgtMWFjMS00YThiLWE2MGMtZWRjNjFmZDcxZjk1',
#  'YTIxY2M3ZTUtMGU0NS00YTI4LTk5ODktZjUwMDE3NThhODQ5',
#  'MjU1Y2NhOGItNDE3My00OTQwLTg2YzktMDFkNmM0YzRhYzM0',
#  'YzZmMGM3YjUtNzI2NC00ODg5LTljZmQtMTllMjdmMzg3MDJl',
#  'Yzg2YTBhZGEtNGUyNC00MjYyLWEzZTQtZWE1YTBlMDAwNzYx',
#  'NGRmZTUyYzItMGQ5Ni00OTQ0LTk2MmItMzI1NmI2MDA0NjMz',
#  'YzBjMDhkOWItMTUyYS00YjA2LThjYWYtOGFiMTJhMjRjOWJl',
#  'MGQyZDBlMjEtZTYwOS00YzQ3LTgwNGItNDAzY2YyOTE5MTVi',
#  'MTE3ZWVkODktMTJiOS00ZjlmLWEzYmEtZmYwZmEzODMwOGJk',
#  'NDE3ZTNiYmUtNDc1YS00MGQ0LThkMTYtMWFlNDQzOGMyZDYx',
#  'NTQ4ZDI5YjEtM2MyYi00M2JkLThkNDktYzhkYWEwZDNjNWVi',
#  'MDA3YTc4MDctMDdjZC00MGZkLWJiOTMtOWQ2OGVhZWU0MDkw',
#  'ODJlNTIzNzYtOTczMy00NGFkLWJiMDktZGYwMjVmOGI2NTVj',
#  'MTk5ZWIyMjktNDI3Mi00ZDYxLThhZGMtOTcyNTRjMzc0M2Vh',
#  'NGFmY2NlODAtZDAzMC00NGZjLWI3MDUtN2M5MjhkZTExMTY5',
#  'NThhNWNiNDAtZWMxZC00YzE3LTg1N2YtNjI1MGQwZDZjYWJl',
#  'OTBlZmM5ZWMtYzQ2My00OGIzLWJmOTEtM2VhMWRjZjIxNzI0',
#  'OWE2NjczNGItNjgzNy00NGZmLWIxYzItNzNhMTRkMWIxZjdh',
#  'NDA4ZTJhNjgtZjExNC00N2EzLTliNzMtNGVkYzBkNDQ0Zjc2',
#  'NzEyM2VhOTQtNGY1Yy00NzYxLWFlYmMtNTYzOWE3ZmNiYzY5',
#  'N2UxNTZhMDQtMjEwMy00NDc2LTg5ZWMtZmQ0OGVjNmE3YmE1',
#  'Yjg5MDZlNTMtZWRiZC00M2ZjLTgyYmEtNjhmYmE1OThkNjI4',
#  'MzFlNTIwMGUtM2YwNi00YjE0LWFjYTAtZTk1NWRiYTE0Yjg1',
#  'NmJmZmVjOGEtOTc0My00NzM5LTk3ZmYtOTcwZDFlNjU0ZWJi',
#  'YmNkN2Y4NWEtZjllMC00NTExLWE0ZjItYzhmZGE5ZjE5MjUx',
#  'N2Q1NTQzZTUtM2EzMy00ZTZlLTg1NzEtYWEwMWU3ODA3Yzcy',
#  'OTYyYzAzZDQtM2FjMC00OTYxLThhODUtNzg3YTk1NTQ1ZjZi',
#  'NDkwNDUyN2QtZTRkMS00MDBiLWE0NmQtNDdiMmE2NzIxYjRj',
#  'OWMwMTkzZjMtNjAwNC00YWM2LWI0OTQtY2EwZGQxMDI2ZTg3',
#  'YmNiOWE2NzAtMmZiMS00N2Q0LWFiODgtYjFiNWMwNWJhOTA1',
#  'YWE3Y2FhMWItZDhmOS00YTlmLThiZjUtMTAwNGQxMWY2MWFh',
#  'MGZiNGUxNGMtYzlkNC00ZjcyLWEwODYtOTM0YzBiNzY4ZjQ2',
#  'MGJjODkwYmItZDY3YS00OTgzLTlhNWQtNjMyOTUwY2IxNjE0',
#  'YzIwMjkwMzAtZWEyZC00ZDQ5LThjZWUtMTc0MmE3YmI4MGU3',
#  'ZDEzMDcyZmItYmMxMS00M2JmLWE5NjQtODdkNjYxNGYxMDY2',
#  'MGE0ZWNkYjQtODQ4MS00Yjg5LTkxYTQtMDJkZDQzOTFjMzZl',
#  'MDY0ZDUyMTItNjllZC00ZGE4LTg1MTAtMDJmNmQ0ZjUzNDA2',
#  'ZDNjMDA1MGQtYjg1Zi00MDU1LWFkZjYtNWQxNzdjNGViMDg2',
#  'MDA4OWVkM2YtZDdkYS00MDI3LWIyNTEtY2I0Njk3NTYxYzY1',
#  'ZjhlMDlmNTYtM2Y0Yy00ZTI0LThmNjEtNTlmNTRhMjEzNGFj',
#  'MmJhNzllMjktNDQ2NS00ZDE5LTkxYjMtMGJkMjM3MTg1MzAz',
#  'MmYzNmUxYjUtMTBhNy00Y2ZhLTk0MmQtMjFkZjg5OTA4ZmU0',
#  'MmM5ZmI3NDItMjI0Yy00ZjI2LWI1MTUtNjcxMzc1MmQ4NmRl',
#  'NjdlMDZjMDAtNDE5Yi00OTg1LWI4YTMtOWViYzVkODczM2Iy',
#  'OTQ1YWRiNDctMmEzMC00YTk5LTgwMTktZjMzMjQ0ZmI3NTAw',
#  'MDZmODVkMTEtOTk0ZS00YjQyLTg1ODAtYTYyZGUzNjcyNWE2',
#  'MGUzMWVjYmYtYTNkNS00NTljLWIyYjQtYTMwNDdmYmVhZjll',
#  'YzcwZWZlNjQtMzVhOC00NDI0LWFjMTAtY2Y2MDc4MTY2MzRk',
#  'Njg3ZTljOWUtMTI1YS00ODIwLTg0MDAtYWUwMzE1NTFhNTQw',
#  'NDk5YTY5NmUtZGY3OS00NDEwLTljNzUtYWUyNmUwNmQwNzI5',
#  'NDNmY2FlZDktNzUxYi00NjQ4LWFkYmUtYTRhYTIwMWQxNDI1',
#  'NWY2NjQ1NGItZWQ5OC00YTZjLTg2ZWYtZjczYzYwMGQ3YjFk',
#  'ZmJjMWRhMDEtMWFjYy00NDkzLWI0MmUtNWQ1NzNjNTA0ZjQ0',
#  'ZDIwOTQ4ZjYtM2JiMi00ZDliLWI4ZDMtNDQxMjE3ODFlMjI5',
#  'YTgwYTFmYTUtZTFlMS00Y2Y0LWE1MzctYTUwNmFlODcxZDVl',
#  'ZjZhZDRkMzgtZjQ2MC00OTdjLTg1MzctNzZjZmQ1MjBjYmIw',
#  'NzNlMGUyNzgtOTZmNC00MWI3LTk1ZGItNDViNzJiZDA2M2Nj',
#  'NmFhZDIxMjMtZTY2Ny00N2Q1LThjNTUtMDJkMDlhMTIwYTg4',
#  'NDhlMjZhOWMtMmFkMy00NzViLThlNWMtZjFmMjc2ZWRkMmFj',
#  'YzkyNmRmYzgtZGFjMy00NWJmLWI2YjMtMjYwMmRmOTBjYmNl',
#  'MDczYTY4MjktNWIwYy00M2E5LWI0MjQtZWI3N2Y5OGVhYTFj',
#  'NGU1M2MyNTMtM2MxNC00ZjZhLTlmYTctN2FkMDlkM2Q3NDQ4',
#  'YTIzYWUwNTctMjYxYy00ZDFmLTk2MmMtMzBiMWFlMDA2YzY3',
#  'ZGM0YWE4YTYtOTAyMi00YWZjLTg1MGYtNjIwMGM3MWViNGFj',
#  'NzdkNWMwZGMtOTc4Ny00OTM5LWI1ZTctYmUxZWMwM2JhNWYw',
#  'MGI5MDM0MmEtODM5OC00MTI4LWFhZmEtY2YyNjIxZGZkZDhl',
#  'YmI4MWI3ZjMtN2NjZi00ZWE1LTkzOTktNTJiMTE1YjM4YjEx',
#  'Y2ZkNTMwOGYtY2U5OS00MzZjLTkwYjEtMzY4NDQ5MmYzZmVl',
#  'ODI0YWU5ZWItODQ3Ni00MzEzLWFkOTYtOTViZTlkZDYwNzg0',
#  'ZGZjNWU3NjEtYTAxMy00NmE5LTg5ZGItYTEwNzE0MTYxZGJi',
#  'YTk2YjBlNjYtMWU3YS00MWM4LTlmN2MtZmU4ZGEwN2Y5ZmMw',
#  'MWJjYzNlN2EtNmFjMS00YjVhLWJjYjAtZWVlYWRiNjc4MDNj',
#  'Y2FlN2MzZTEtYjAwZi00ODA1LThkMjEtYjcwZGRhYjM3ZThm',
#  'NDBmZjA0YTYtOWQ4NC00MDAxLTgwODgtNDlkODBkNmQxNWZi',
#  'YWIzYzc3YzgtNmY2ZS00NGQ4LTlmNTEtYjY5OTdiMzU1OTE5',
#  'Njc2ZTM1YWQtYTMyNy00Njk1LTg5MjctZDFlMzhlODk1NmI0',
#  'MmUyYmNmZWItMjAyNS00ZDUzLWFjYjMtOWM3ZTI3ZjY3ODNl',
#  'OTk5NjBlMTQtOTdjNy00YTdjLWE2ZDQtNzAxODI1ZDMzYjIy',
#  'NDZhMDhhYjItNzZjYS00MDViLTk5NTUtYWExN2RlNzM0ZTgy',
#  'ZGEyOWU0M2UtMTgyNS00YWUwLThiZDMtNzBhZTYxMTU2NzZl',
#  'YzQxOWE2YzctNzI0My00ZmU4LTg2NGUtNGRlNTMyNTYxNjYw',
#  'NGEwYTkzOGUtNjQ5ZS00YzA4LWEyM2ItNDU4MjNkMTY1OTRj',
#  'NTliNGQyMjctYmI5OC00ZThlLTljNzEtYTY3NTg1YjYwOWZi',
#  'NGY2ZDU1NjYtZWYwOS00N2I4LTg3NTgtOWYxYTMwZjg5MWFk',
#  'MzQ4YTg5NWYtYTQ3Mi00NjExLThmMmItNTY0ZThiNWIxZjc1',
#  'MWZlZTM3NmUtNTE0YS00YmY4LTg1N2QtYjVmNWNkZWJmMmNj',
#  'MTNmM2Y4NGMtYmJhNy00ZjU5LThhYzYtODAyNDFlMjQzZDFi',
#  'Y2RjM2M5YTgtMzFlNi00NjAxLTk1ZmQtZDNmMmZhZGQyZDJk',
#  'OTQ4ODgyN2EtYmUxZi00ZmZmLWIwMjMtZGI4MDJkODE2ZjJk',
#  'MjJjZGQ3NjMtMDVlMC00NmIxLWI5MDMtZDAwOWJjZWI0YWVh',
#  'MGM1NjAwOTUtYTE4Ny00NTMyLWE5YzMtMGZiOWMyNDM5ZWYz',
#  'YmIwYzUwNWUtODYwMC00MzRlLTg5YmEtZTAzODAxN2Q0OWQ2',
#  'OTIxOWZhNjMtNTI3Yi00ZTM4LTlkZGQtNDRiNTJkMDM1ODY2',
#  'ODEzMjM2MzItMmNkNS00MDZjLWE3NmYtY2JhNDJmNjM2NzE1',
#  'NDVlZGM3NzItZmVjYy00NGM3LTliYmItMmZlYjNlMGNiYWVm',
#  'MjM0NzgwZWItMzI5ZS00NWY0LWJmMmEtMGYxMjliZThmYzAz',
#  'NTU4OTgzMmEtMjMxOC00MDRmLWJjNTItNDk5MWFhZjQ4ZDI4',
#  'NGE3NDE4N2QtZTAwZi00Y2Y5LWE1NTItN2RkNzRlNzc4NDdk',
#  'ZGJhOGEzZDctNjBlNi00ZTcyLThmOTYtZTA1YWE2NGU3Njc2',
#  'Y2RlNjEwMmYtMDhjNS00OTFiLWI3NDktZWJiNjYxNTllZmM0',
#  'ZDM0NzJjY2EtYWRmMS00NjhiLTgwOWUtZjk0ZDg5YTgxNjgz',
#  'NzEwZTBmNTQtZTJhMy00OGI4LThiM2MtODk1ZTBhZDc2MDVj',
#  'M2U3MGY2OTctMzY3Yi00NDM2LWIzNjQtODBiNzkzMWQ2Yjgw',
#  'ZTZhZjNjMmYtOGI4ZS00ODZlLTk0MTQtNjM0ZGRkMDJlMzU5',
#  'NmZjNDM2ZjAtMmY5Zi00NGJhLWFlMDYtOGU5YmE2MmE3NDZm',
#  'YmRmNzA5M2MtZmI1ZS00NTY1LWJiYTQtYmMwNWY0NDU1MWUw',
#  'YzY1YTc3NTEtOGUyMy00OWE3LWI3YmYtYjY4ODY1YmJlZjdk',
#  'YzllNDdlMWMtODI4MS00NjkwLTgyMjYtN2ZhM2E1ZTcyMmRl',
#  'N2YxYTc0MWMtMDM1OS00ZjIxLTkzZjctZmYyZGQyYjU0MTcx',
#  'YTcxMWM4OWYtZjNiYy00MjcxLTg3YzEtZDczMmRjYWQxZDhh',
#  'ZmQ2MmExZWUtZDFlNC00OGQwLWJhY2UtNzZiZDg5ZmY5MDJk',
#  'ZWRhM2ZkZDgtMWE5My00NTkxLWE2NzEtNWRlZTQwZWVhNWYy',
#  'NTNlMTgwOTUtYWUyYy00MDA4LWFmOWQtZDNkMzlhZjhkNmUz',
#  'NDNiZmI2MTUtYzA5OC00NTZjLWIxZDUtMDhhN2FiODk4MWUx',
#  'NzYwNWM5YmUtMmI3NC00YWE5LWI0NWMtYWZjZjE1ZDQwM2Jm',
#  'ZDE0YWI2ZGYtZGIyNS00OGViLWI4ODctZmY2YjQ4Mzk3ZDVj',
#  'OTk3ZjdjZjgtMDc0Zi00NDUyLThkMzEtZGZlZGVlYTJjM2Iw',
#  'MjZiMGQ0MDgtMWI1MS00ZmFjLWFlZWYtMTY0OThiMmVjNGQ2',
#  'NDdkMTMyNjAtNzE0NS00MTc1LWIxOTItYjMyN2ZjYzBiNWI0',
#  'MzVkNzE3MzYtMmE5Ny00MDU0LWE2NTgtZDZmZjU3NWVjMWI5',
#  'YTM2NmEzMDktMWFiYS00YTFlLTgwYjItMjIyYjBjYmE0NjUz',
#  'NDVmMWVjYWMtZDhlZS00ZjdkLWI4NWEtMzQ1OTFkODQwYmU3',
#  'NjU5OGZjZTYtODBmNS00NjZhLTk0ZjQtZDFmNzkwODg2MGEx',
#  'MjAwYTc1NDEtYzUyYy00ODJiLWFlNjYtNzM4MWRlZDdkNjMz',
#  'Zjk3ZDM0ZDEtNTRmZC00MmEyLTkwYWEtOWVkMDZlZDY3NzQz',
#  'YTNhZTBhMmItNGYwMS00ZWNmLTk3ZTAtNDcxM2NlMTFjNDky',
#  'MWNjNGQxM2MtNWE0Mi00YmU3LThmYzktZDMxZmViMWVjOGVk',
#  'NzJhNjFjMWItMWIyZS00MjM5LTk2ZjItM2IyNGIyN2ZkNzJk',
#  'MmM4MjBiMTMtYWQ5Mi00ZTZjLWI4ZDgtNDE5NWMzMDQwMDYy',
#  'ZTMxMzMwYmQtZTI4Yy00OWJhLWJjOTMtOTg4ZWFmZGIzNjg1',
#  'ODZjNzY4MjktZjViNy00MDZmLWI4Y2QtNWQ5NTczZGZlNWFm',
#  'OGEwNDkwNTMtNDY1Yi00ZjA0LTkzNDEtNGRmZjIyOGNjYjE1',
#  'YTUwNjYyODYtMThjZS00NDMxLTk1NTEtMjQ2MWU5NzY5OTVi',
#  'MDc4NTk5YjMtNjUwZi00NzIxLWExNmEtMGI1NmI1ZDZmMTI2',
#  'N2YyMGRiM2YtNTRhYS00MThhLTg4ODgtOWQ0ZGFkODg1ZDll',
#  'YzYwMzRmOWQtZGU0Ni00OWJiLWE3NGUtODliMGNlMDNkZWI3',
#  'MTlmMWY1ZDUtMzk0OS00ZGE3LTk3OWMtYjJkMjgxNDVmZmM0',
#  'ZWI5YWQyNDMtMjA5YS00OTNmLWFhNTAtOTUwMjZhNjI0ODZl',
#  'MTNlMzkwZTMtMmRmYS00ZWYyLThiMDEtZTg3MWNlNDRmMzk1',
#  'YTlkZGExM2MtZThlZC00ZWVlLTkzNTctZGQ5ODFlNDA2ZjU4',
#  'MWRiNTEyOTUtNGExYi00ODhlLWEwYWMtM2U4MThhNDZiYWIy',
#  'MGIwOGFlYWEtNjhjYS00ZmNjLTg3ZjYtYTE4YjEzNjY0NDUx',
#  'YjRmOTc3OTYtMmE5YS00NGYzLTgxNDMtZTNjM2UxZjFjYTg5',
#  'OWZkNjEyOTYtMDI5OC00NGZiLWFmOWQtMjA3ZWFlMGE1NmM5',
#  'ODYwNDhhZjctYWJjNS00MGQxLThkZGItYmZlZTdjMmExZDE3',
#  'YmFmYzRiZTUtNGJkMy00NWQ2LWFlNjktOTFjMjYxMmViZWIw',
#  'ZTJiMzBjYzctNDVjOS00NTk0LWI4ZjEtNDk5NGI4NDBjMzU2',
#  'ODk2MzYwNTUtMzBlMy00MTJhLWI3ZTctMDU3MjU0MjFkYjIz',
#  'ZDY2Y2YwOTctYTlmNi00NzJjLTg3OWYtYzdjOTI0ZWI0ZThm',
#  'MDUxNTg4YjEtNDY1MS00MTg3LWE3NjEtYjA3N2I5NGFkNGJi',
#  'MGZiNDYwY2MtYzIzNC00Zjc4LTk5YjEtZjY5YTViNzgxMGU4',
#  'NGU2OTZmN2YtY2NkYy00ZGMyLWE5YWYtOTg4YWI5YzY0MTE5',
#  'NTE1NTMxNDQtYjA0My00NzhiLTg4YmMtMTFjMjliOWIyMzE1',
#  'MDU2Njk1NzEtZWMzMy00OTgyLTg2NmQtZTliM2I0NzlmNjRl',
#  'ZTE5NjI0YmQtYzUwNS00Njg4LTkyMDAtNGFhZjlhOWMyN2Mw',
#  'NDc4Yzk0MWItMzIwMi00YWFjLWEzOWYtMjRkNDIyZjQ1YTlm',
#  'YzJiNjI0MDctMjRhYi00NjJlLTk4NzAtYWQzNmUwN2Y4OWEw',
#  'NjU2YzY3ZjYtMGMwMy00YjIyLTljNDYtZThjODY4NGE3ZTFj',
#  'ODJiYjNjODctMzFkMi00NjhiLTgzOWQtNjQ0NWZkYjIzMDgw',
#  'MzU5Njg2NDMtYzFiYS00Zjg1LWJkODUtNTdlYzUyMmIyMGVk',
#  'YjU0N2M0YTktNDc1MS00OTM1LTk1YjYtNmRiMTk5ZWNlMmVl',
#  'NGZlMDg4NDctYjU4Ny00OWM5LThmNmYtYjRkYTVmZDg1MmQ4',
#  'YWU1Njc4ZGYtYmUwYy00MTFmLTk1NTgtNjUyY2FjMmU1NzM1',
#  'ZmNiZTAxNDQtMmQ2NS00NDlkLWE5NjgtZGVlYjZlNWFmNTA4',
#  'ZGU4ZmU0Y2MtYWY4ZC00ZWVlLTk1YmEtNDJjOTYxYWZlYmVk',
#  'ZjM2OTRiMTYtMTQ3Yy00MGU0LThhNzgtM2RjYjliYmE5NzI4',
#  'Y2UzODZlMDktZmEwZC00NDlhLTljNjgtYzdmYWUwMzZhMWY5',
#  'NTEyMTdhZmYtMzVkYy00NWE5LWFlZjgtNGNlODA0NzRhYzlk',
#  'NjBkMjk4NGUtOGI4ZS00OTFjLTliNzEtYmVkYzEzYzljOTg0',
#  'YjJmYzI3NzQtOTE5NS00YjVlLTkzNTYtZmY4Njc5MDBlNDM0',
#  'Y2VlZTJiZWItMmQ4MC00NGFiLTliN2MtNzMxNzNiNjc1MWZj',
#  'MDQwMjliYTgtMzQ5Ni00ZGU4LThhZWMtMDVlYjM0Zjc2NWQz',
#  ...]

# %%
# Retrieve (hybrid_score_threshold - first 30 results)
# Retrieve (hybrid_score_threshold - first 30 results)
retriever = vector_store.as_retriever(hybrid_score_threshold=30)

# %%
# Generate

# Take all the result documents from the retriever and format them into a single string suitable for input into the language model.
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)
# Use the ChatPromptTemplate to define the prompt that will be sent to the model (Human) remember to include the question and the context.
# you should have the system prompt and add the context (the retreived documents) at the end, then the human prompt with the question.

prompt_template = ChatPromptTemplate.from_messages(
    messages=[
        ("system", f"{system_prompt}. Context = {stored_chunked_documents}"),
        ("human", "{question}")
    ]
)


# Define the Chain to get the answer: the chain should include:
# 1. the retriever that get the documents and perform the format_doc function with the question passed using the RunnablePassthrough()
# 2. the prompt generated
# 3. send it to the llm model
# 4. parse the output using the StrOutputParser()

rag_chain = retriever | format_docs | prompt_template | llm | StrOutputParser()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 11
#       5     return "\n\n".join(doc.page_content for doc in docs)
#       6 # Use the ChatPromptTemplate to define the prompt that will be sent to the model (Human) remember to include the question and the context.
#       7 # you should have the system prompt and add the context (the retreived documents) at the end, then the human prompt with the question.
#       9 prompt_template = ChatPromptTemplate.from_messages(
#      10     messages=[
# ---> 11         ("system", f"{system_prompt}. Context = {stored_chunked_documents}"),
#      12         ("human", "{question}")
#      13     ]
#      14 )
#      17 # Define the Chain to get the answer: the chain should include:
#      18 # 1. the retriever that get the documents and perform the format_doc function with the question passed using the RunnablePassthrough()
#      19 # 2. the prompt generated
#      20 # 3. send it to the llm model
#      21 # 4. parse the output using the StrOutputParser()
#      23 rag_chain = retriever | format_docs | prompt_template | llm | StrOutputParser()
#
# NameError: name 'stored_chunked_documents' is not defined

# %%
# Test the solution
for QUESTION in QUESTIONS:
    print(f"QUESTION: {QUESTION}")
    print(rag_chain.invoke(QUESTION))
    print("--------------------------------------------------")
